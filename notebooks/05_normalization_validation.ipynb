# %% [markdown]
# # 05 · Does the normalization gain survive other periods?
#
# **Objective:** finish the predeclared three-variant, three-fold feature ablation. Reuse the three completed first-fold models. At most **six new CPU fits**, no control refits, no tuning, no new feature definitions in this notebook. The original **300-second cumulative study budget** remains in force; approximately **228.51 seconds** remained in the returned report. No final-test observations are scored. Use **Commodity - manual (verified)**.
#
# The first-fold price gain is **+0.003786**; volume confirmation is **+0.001157**; the union is **−0.017654**. This is a small screening signal, not proof. The union is included only to finish the **already-declared interaction ablation**, not to tune or expand the negative result. **Run All starts this bounded continuation.**

# %% [markdown]
# ## Publication provenance
#
# This is a publication copy, not a new execution. Original code cells: 12; cells with execution counts: 12; original error outputs: 0; inline Plotly outputs retained: 8. Console logs, table/HTML output, attachments and tracebacks were omitted from this copy. The original remains in the research workspace. An execution count alone is not proof of success. Refer to the linked result ledger for completed/failed/pending study status. Interactive figure data are disclosed with this public notebook.

# %%
from pathlib import Path
import os, importlib.util
import pandas as pd
from IPython.display import display, Markdown
ROOT = Path(os.environ.get('COMMODITY_MANUAL_PROJECT', '/home/sagemaker-user/projects/commodity-prediction-manual'))
spec = importlib.util.spec_from_file_location('manual_feature_round', ROOT / 'scripts/commodity_feature_round.py')
support = importlib.util.module_from_spec(spec)
spec.loader.exec_module(support)
previous = support.support(ROOT)
ready = previous.readiness(ROOT)
previous.validate_runtime(ROOT, ready)
print('Source:', ready['source_commit'])
print('Verified kernel. No new fitting has started in this cell.')

# %% [markdown]
# ## Analysis plan frozen before the remaining periods
#
# Fold 0 is reused: train `<1164`, validate `1169–1348`. Fold 1: train `<1344`, validate `1349–1528`. Fold 2: train `<1524`, validate `1529–1703`. The pooled metric is computed from **all 535 daily correlations**, **not the average of fold metrics**. All model-fitting rows follow the existing warmup and purging policy.
#
# The descriptive review rule is: positive pooled gain, gains on at least 2/3 folds, and positive gain on the **later 355 dates**. It was declared after seeing fold 0, before seeing the later results; it is **not** an unbiased statistical significance test. Report every variant, whether it passes or fails. The five predeclared contrasts use 10/20/40-date blocks; within-family intervals do not correct the entire adaptive research history. No model is automatically promoted.

# %%
display(pd.DataFrame(support.FOLDS, columns=['Fold', 'Train stop exclusive', 'Validation start', 'Validation stop exclusive']))
print('Recorded cumulative seconds:', previous.budget_used(ROOT))
print('Do not rerun notebook 04 or reset its budget.')

# %% [markdown]
# ## Supervised execution: verify → exact control replay → six remaining fits → exact child replay
#
# Every completed checkpoint is protected by a seal and the first-fold files are compared with the supplied report hashes. A previous failed/interrupted run stops for diagnosis; a completed result reopens without fitting. Each successful new model has its own checkpoint. Do not start another terminal worker in parallel.

# %%
report = support.run_validation(ROOT)
print('RESULT:', report['status'])
print('New fits in this notebook call:', report.get('new_fits_this_notebook_call', report['new_training_fits']))
print('First-fold refits:', report['first_fold_refits'], '| Control refits:', report['control_refits'])
display(pd.DataFrame(report['comparison_rows']).drop(columns=['fold_scores','fold_deltas']))
figures = support.validation_charts(report)

# %% [markdown]
# ## 1. Pooled performance

# %%
figures[0][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## 2. Fold stability

# %%
figures[1][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## 3. Matched per-fold gains

# %%
figures[2][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## 4. Later-period transfer

# %%
figures[3][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## 5. Uncertainty, not just the best point estimate

# %%
figures[4][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## 6. Temporal concentration of information

# %%
figures[5][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## 7. Feature admission

# %%
figures[6][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## 8. Horizon diagnostics

# %%
figures[7][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Preserve the evidence
#
# The private ZIP contains nine models and their predictions/manifests, not raw data. Download it locally; **do not attach it to chat or public GitHub**. The HTML uses inline Plotly, no Chrome/Kaleido. Save the notebook with Ctrl+S. If execution stopped, return its report and do not run notebook 06. On a completed run, notebook 06 is the next separate, zero-fit training-only milestone. Then stop the space.

# %%
completed = support.finish_validation(ROOT, report, figures)
print('RESULT:', completed['status'])
print('DECISION:', completed['decision'])
print('REPORT:', support.result_path(ROOT))
print('DASHBOARD:', completed['dashboard'])
print('PRIVATE BACKUP:', completed.get('private_checkpoint_bundle',{}).get('path',completed.get('backup_warning','Not created')))
print('Save this notebook. No model is promoted; feature engineering stays open.')
