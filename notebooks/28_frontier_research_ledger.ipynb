# %% [markdown]
# # Commodity forecasting | Frontier research ledger
# **Alvaro Mendizabal** · executed aggregate-evidence presentation
#
# No model fitting or restricted competition rows are included.

# %%
import plotly.graph_objects as go
families=['Retained panel','Transformer','Zero-fit adaptation','Online-refit blend','Group-wise blend']
scores=[0.2893649296119325,0.2532312989035328,0.2807133550080609,0.2971141398128422,0.27325045742086795]
fig=go.Figure(go.Bar(x=families,y=scores,text=[f'{x:.6f}' for x in scores],textposition='outside'))
fig.add_hline(y=0.2893649296119325,line_dash='dash')
fig.update_layout(title='Matched later-period frontier scores',yaxis_title='Local metric',width=1000,height=480)
fig.show()
# Out:
# Figure: matched later-period frontier scores

# %%
families=['Online-refit blend','Group-wise blend']
fold1=[0.02358894141274387,0.00013928741408078538]
fold2=[-0.009508797203819364,-0.0268774306726976]
fig=go.Figure([go.Bar(name='later fold 1',x=families,y=fold1),go.Bar(name='later fold 2',x=families,y=fold2)])
fig.add_hline(y=0,line_dash='dash')
fig.update_layout(title='Frozen later-fold transfer deltas',barmode='group',width=900,height=440)
fig.show()
# Out:
# Figure: frozen later-fold transfer deltas

# %%
names=['Online-refit blend','Group-wise blend']
delta=[0.007749210200909684,-0.016114472191064544]
low=[-0.02344894416450144,-0.06878544512092166]
high=[0.03658030338212327,0.03814998401602151]
fig=go.Figure()
for n,d,l,h in zip(names,delta,low,high): fig.add_scatter(x=[l,h],y=[n,n],mode='lines',showlegend=False)
fig.add_scatter(x=delta,y=names,mode='markers',name='Observed delta')
fig.add_vline(x=0,line_dash='dash')
fig.update_layout(title='Paired 95% uncertainty vs retained panel',width=900,height=400)
fig.show()
# Out:
# Figure: paired uncertainty versus retained panel

# %% [markdown]
# ## Active frontier
# The full 15th-place-inspired Attention/Residual/AutoEncoder online ensemble is active. A prior execution completed **51 compatible fits** before an engineering-only singleton BatchNorm minibatch edge case. The repaired runner preserves every training row and reuses old checkpoints only after parent identity and file-hash validation.
#
# No scientific score is claimed until that evaluation completes. The repository still has **no verified official MITSUI leaderboard score**.
