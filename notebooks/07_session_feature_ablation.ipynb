# %% [markdown]
# # 07 · Do session features improve predictions, or only describe coverage?
#
# **One bounded feature experiment: at most four new CPU fits on the first fold.** Keep the saved `current_market` reference. The completed normalization family did not improve the pooled metric; do not append its rejected features or rerun notebooks 04–06. The 11 candidates here were shortlisted using training data only.
#
# **Run All starts fitting in the execution cell.** Worker cap: **240 seconds**, including checks/replay. No other folds, parameter tuning, package install, external data download, ensemble or final-test evaluation. Use **Commodity - manual (verified)**. Keep old directories containing its Python environment.

# %% [markdown]
# ## Publication provenance
#
# This is a publication copy, not a new execution. Original code cells: 13; cells with execution counts: 13; original error outputs: 0; inline Plotly outputs retained: 9. Console logs, table/HTML output, attachments and tracebacks were omitted from this copy. The original remains in the research workspace. An execution count alone is not proof of success. Refer to the linked result ledger for completed/failed/pending study status. Interactive figure data are disclosed with this public notebook.

# %%
from pathlib import Path
import os, importlib.util
import pandas as pd
from IPython.display import display
ROOT=Path(os.environ.get('COMMODITY_MANUAL_PROJECT','/home/sagemaker-user/projects/commodity-prediction-manual'))
spec=importlib.util.spec_from_file_location('session_ablation',ROOT/'scripts/commodity_session_ablation.py')
support=importlib.util.module_from_spec(spec);spec.loader.exec_module(support)
parent,previous=support.previous(ROOT)
ready=previous.readiness(ROOT)
previous.validate_runtime(ROOT,ready)
print('Source:',ready['source_commit'])
print('No training in this cell.')

# %% [markdown]
# ## Hypothesis and information timing
#
# The signed overnight or intraday move of a target pair is formed **before** standardization. Reference means, risks and covariance use rows strictly before the current row. The training screen selected six intraday candidates and five overnight/risk candidates, of which one is overnight risk share. Only 89/424 targets have complete-leg bar definitions. Add a **support-only control** before attributing gains to numeric features.
#
# The source family, windows (21/63/126), clipping rules, shortlist and model settings remain frozen. The old 1164-row candidate checkpoint must exactly match the recomputed prefix before a new fit. An exact duplicate audit compares candidates with the current 87-template base; historical families outside that base are not claimed exhaustively deduplicated. Training-only model screening records all admission/rejection counts.

# %%
validation,screen=support.read_reviews(ROOT,previous)
display(pd.DataFrame(validation['comparison_rows'])[['variant','official_metric','matched_delta','positive_folds']])
display(pd.DataFrame([{'panel':k,'support_flags':2,'numeric_features':len(v)-2} for k,v in support.plan()['variants'].items()]))
print('Train: rows 0–1163; fitting warmup 252; validation: 1169–1348. No later labels are read.')

# %% [markdown]
# ## Preregistered first-fold decision
#
# For an information-bearing panel to earn **review**, its official-metric gain must be at least **0.002** over **both** the saved `current_market` model and the support-only model, with nonzero numeric admission and exact replays. This rule was declared before session-model validation, but after earlier studies used this development fold. It is a cost-control screen, not unbiased significance or model promotion. Seven matched contrasts use 10/20/40-date blocks; intervals condition on these fitted models and do not correct prior adaptive research.

# %% [markdown]
# ## Execute one bounded experiment
#
# This cell may train four models. It replays, but does not refit, the old baseline. Each completed child is sealed separately. Do not start a parallel terminal run. If a previous run stopped, return its report rather than retry unchanged. Completed results reopen without refitting; missing dashboard output can be regenerated independently.

# %%
report=support.run(ROOT)
print('RESULT:',report['status'])
print('New fits this call:',report.get('new_fits_this_notebook_call',report['new_training_fits']))
print('DECISION:',report['decision'])
display(pd.DataFrame(report['comparison_rows']))
figures=support.charts(report)

# %% [markdown]
# ## Prior family conclusion

# %%
figures[0][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Training shortlist rationale

# %%
figures[1][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Structural coverage

# %%
figures[2][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## First-fold performance

# %%
figures[3][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Matched additions versus two controls

# %%
figures[4][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Uncertainty

# %%
figures[5][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Temporal concentration

# %%
figures[6][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Actual feature admission

# %%
figures[7][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Subset effects and limitations

# %%
figures[8][1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Interpretation and next research gate
#
# A good first-fold result must survive later periods; a failed panel should not be tuned unchanged. A support-only gain is not proof that price-session content helps. A change on the other 335 targets can occur because the pooled model is refitted; it is not evidence that those targets acquired OHLC data. No pooled three-fold or leaderboard score is claimed here.
#
# **Coverage agenda:** subsequent separate research should test close-only, cross-asset or legally released-target representations for markets without complete bars, after checking overlap with existing return/risk/relationship features. Carry, inventory and macro-vintage hypotheses require actual dated data; anonymous row IDs are not a calendar.
#
# **Primary research context:** Blanc, Chicheportiche & Bouchaud (2013), [overnight/intraday volatility decomposition](https://arxiv.org/abs/1309.5806), supports separating sessions in a stock-volatility problem—not guaranteed commodity-return alpha. Gorton, Hayashi & Rouwenhorst, [commodity futures fundamentals](https://www.nber.org/papers/w13249), motivates later inventory/basis work only when appropriate instruments and publication timing are available.

# %% [markdown]
# ## Save and stop
#
# Ctrl+S saves notebook outputs. Download the JSON report and this executed notebook. Keep the private checkpoint ZIP on your computer; do not attach models or predictions to chat or public GitHub. Download the self-contained HTML to view charts after stopping AWS. A local ZIP alone is not an off-disk backup. **Stop space in Studio—not Delete space. No automatic shutdown occurs.**

# %%
completed=support.finish(ROOT,report,figures)
print('RESULT:',completed['status'])
print('DECISION:',completed['decision'])
print('REPORT:',support.report_path(ROOT))
print('DASHBOARD:',completed['dashboard'])
print('PRIVATE BACKUP:',completed.get('private_checkpoint_bundle',{}).get('path',completed.get('backup_warning','Not created')))
print('Stop here. No other folds or model promotion. Save notebook, download evidence, then Stop space.')
