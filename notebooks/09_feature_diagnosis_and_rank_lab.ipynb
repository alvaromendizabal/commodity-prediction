# %% [markdown]
# # 09 · Diagnose the representation, then engineer released rank states
#
# **One bounded milestone:** two mask-removal fits plus a training-only 14-candidate laboratory. Do not rerun notebook 08. No old model refits, graph reconstruction, rank-feature fits, package installs, other folds, final test or cloud/Git writes.
#
# **Run All starts up to two new CPU fits.** Worker cap240 seconds; 15-second heartbeats. Use **Commodity - manual (verified)**. Stop the SageMaker space after saving.

# %% [markdown]
# ## Publication provenance
#
# This is a publication copy, not a new execution. Original code cells: 15; cells with execution counts: 15; original error outputs: 0; inline Plotly outputs retained: 10. Console logs, table/HTML output, attachments and tracebacks were omitted from this copy. The original remains in the research workspace. An execution count alone is not proof of success. Refer to the linked result ledger for completed/failed/pending study status. Interactive figure data are disclosed with this public notebook.

# %%
from pathlib import Path
import os, importlib.util
import pandas as pd
from IPython.display import display
ROOT=Path(os.environ.get('COMMODITY_MANUAL_PROJECT','/home/sagemaker-user/projects/commodity-prediction-manual'))
spec=importlib.util.spec_from_file_location('feature_diagnosis',ROOT/'scripts/commodity_feature_diagnosis.py')
support=importlib.util.module_from_spec(spec);spec.loader.exec_module(support)
network,session,older,utilities=support.previous(ROOT)
ready=utilities.readiness(ROOT)
utilities.validate_runtime(ROOT,ready)
print('Verified source:',ready['source_commit'])

# %% [markdown]
# ## Why not immediately add another large feature family?
#
# The numerical graph panels were tested *with* four explicit availability inputs, and availability-only already underperformed. Two removal fits distinguish that representation choice from the numerical signals. This is a changed, diagnostic test—not an unchanged retry.

# %%
old=support.read_network(ROOT,network,session,utilities)
display(pd.DataFrame(old['comparison_rows'])[['variant','official_metric','delta_vs_current_market','numeric_admitted']])
print('First-fold reference:',old['control']['official_metric'])
print('Pooled reference (different scope):',old['prior_control_pooled'])
display(pd.DataFrame([{'new_fit':n,'existing_masked_reference':v,'numeric_inputs':6,'explicit_masks':0} for n,v in support.VARIANTS.items()]))

# %% [markdown]
# ## New feature laboratory: ordinal state under legal release timing
#
# For prediction t, a complete origin cohort uses outcomes from t−5 at the latest. Rank observed targets globally and within horizon; never rank against unreleased labels. Construct latest positions, 21/63-observation EMA states, their trend and innovations, plus global/within-horizon contrasts. Keep two coverage diagnostics separate.
#
# Twelve numerical + two coverage templates. Only training rows0–1163 are provided to this lab. Training-half agreement shortlists at most6; **no rank-state model is fitted**. Existing static-rank and raw-return-prior experiments are not rerun. See docs/manual_feature_diagnosis.md.

# %%
display(pd.DataFrame([{'candidate':n,'kind':'numeric' if n in support.RANK_NUMERIC else 'coverage diagnostic'} for n in support.RANK_NUMERIC+support.RANK_MASKS]))
print('Latest permitted source origin at training end:',1163-support.DELAY)

# %% [markdown]
# ## Execute once
#
# This cell launches the bounded worker. Old original/masked predictions must replay exactly. The cached graph cube is used without re-estimating any link. If the worker stops, retain the error and report; do not reset the budget or delete completed stages.

# %%
report=support.run(ROOT)
print('RESULT:',report['status'])
print('Diagnostic fits this call:',report['new_fits_this_notebook_call'])
print('Network decision:',report['decision'])
print('Rank lab:',report['rank_decision'])
figures=support.charts(report)

# %% [markdown]
# ## Prior matched result

# %%
figures[0][1].show()

# %% [markdown]
# ## Numeric-only comparison

# %%
figures[1][1].show()

# %% [markdown]
# ## Did removing explicit masks help?

# %%
figures[2][1].show()

# %% [markdown]
# ## Uncertainty, not a promise

# %%
figures[3][1].show()

# %% [markdown]
# ## Time concentration, not profit

# %%
figures[4][1].show()

# %% [markdown]
# ## Feature admission

# %%
figures[5][1].show()

# %% [markdown]
# ## Information availability

# %%
figures[6][1].show()

# %% [markdown]
# ## Training coverage

# %%
figures[7][1].show()

# %% [markdown]
# ## Training-half associations

# %%
figures[8][1].show()

# %% [markdown]
# ## Availability stability

# %%
figures[9][1].show()

# %% [markdown]
# ## Candidate and result decisions
#
# A numeric panel requires +0.002 against both old references for review. This is a budget gate, not a significance claim. Repeated fold reuse remains adaptive; no automatic further folds. Rank-screen associations are not validation gains. A shortlist of zero is an informative result, not permission to alter the cutoff until features pass.
#
# Source and local additions have separate status: no GitHub commit or AWS synchronization is performed by this notebook. Preserve original worktrees and private records.

# %%
display(pd.DataFrame(report['comparison_rows']))
display(pd.DataFrame(report['rank_lab']['rows'])[['name','training_coverage','half_1_mean_ic','half_2_mean_ic','screen_exclusion']])
print('Training-only shortlist:',report['rank_lab']['shortlist'])
report=support.finish(ROOT,report,figures)
print('RESULT:',report['status'])
print('REPORT:',support.report_path(ROOT))
print('DASHBOARD:',report['dashboard'])
print('PRIVATE_BACKUP:',report.get('private_checkpoint_bundle',{}).get('path','not created'))
if report.get('backup_warning'): print('BACKUP_WARNING:',report['backup_warning'])
print('Save notebook; download JSON/HTML and keep ZIP privately. Then STOP SPACE, not Delete.')
