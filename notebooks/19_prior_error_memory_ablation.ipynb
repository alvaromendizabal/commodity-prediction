# %% [markdown]
# # 19 · Prior error memory: observable historical bias and error shape
#
# Feature research. Prepared, not executed. Run only after corrected rounds16–17 have been reviewed and the new user-run preflight passes. A runtime error stops the milestone. No account operations, package installation, model promotion or final-test evaluation.

# %% [markdown]
# ## Publication provenance
#
# This is a publication copy, not a new execution. Original code cells: 16; cells with execution counts: 16; original error outputs: 0; inline Plotly outputs retained: 10. Console logs, table/HTML output, attachments and tracebacks were omitted from this copy. The original remains in the research workspace. An execution count alone is not proof of success. Refer to the linked result ledger for completed/failed/pending study status. Interactive figure data are disclosed with this public notebook.

# %%
from pathlib import Path
import sys, importlib.util
import pandas as pd
import plotly.io as pio
from IPython.display import display
ROOT=Path('/home/sagemaker-user/projects/commodity-prediction-manual')
ROUND=19
sys.path.insert(0,str(ROOT/'scripts'))
sys.path.insert(0,str(ROOT/'src'))
spec=importlib.util.spec_from_file_location('commodity_next_research',ROOT/'scripts/commodity_next_research.py')
support=importlib.util.module_from_spec(spec)
spec.loader.exec_module(support)
pio.renderers.default='plotly_mimetype'
gate=support.test_gate(ROOT)
print('User-executed gate:',gate['status'])
print('Interpreter:',sys.executable)
# Out:
# User-executed gate: NEXT_PREFLIGHT_PASSED
# Interpreter: /home/sagemaker-user/projects/commodity-prediction-current/.venv/bin/python

# %% [markdown]
# ## Mechanism and evidence boundary
# This round measures already released errors of the historical causal prior at the original prediction origin. These are not in-sample errors from the learned forecasting model. As-of prior values must not be replaced with later revised estimates.
#
# The original forecaster and its settings remain fixed. No success is assumed from a feature name or a training association.

# %%
declaration=support.plan(ROUND)
display(pd.DataFrame([{'Setting':k,'Value':str(declaration[k])} for k in ['candidate_templates','panel_sizes','validation_start','validation_stop','new_fit_limit','worker_limit_seconds','release_delay','acceptance']]))
# Out:
#                 Setting                                              Value
# 0   candidate_templates                                                 24
# 1           panel_sizes                                    [6, 15, 15, 24]
# 2      validation_start                                               1529
# 3       validation_stop                                               1704
# 4         new_fit_limit                                                  4
# 5  worker_limit_seconds                                              240.0
# 6         release_delay                                     per-target h+1
# 7            acceptance  Every declared delta >=0.002; at least one non...

# %% [markdown]
# ## Availability and controls
# All outcomes enter these new features only at origin+h+1. The clock-only panel isolates observation-pattern information from the numerical statistics. Training-only missingness/constant/duplicate checks report every dropped input. The last development period has been inspected before; it is not the final holdout.

# %%
print('Matched control:',declaration['baseline_score'])
print('Correct scope: 175 origins, 1529–1703. This is not the pooled 535-origin score.')
print('Raw/final-test data are not exported by this notebook.')
# Out:
# Matched control: 0.39061886486364056
# Correct scope: 175 origins, 1529–1703. This is not the pooled 535-origin score.
# Raw/final-test data are not exported by this notebook.

# %% [markdown]
# ## Execute the bounded worker once
# At most four new private-data fits. Existing controls are replayed, not refitted. Feature prefixes and saved artifacts must match. A worker or gate failure requires inspection; do not repeat Run All unchanged.

# %%
report=support.run(ROOT,round_number=ROUND)
if report['status'] not in support.DONE:
    raise RuntimeError('Round not complete; preserve its report and do not bypass the gate.')
print('Decision:',report['decision'])
print('Total new fits:',report['new_training_fits'])
print('Cumulative worker seconds:',report['cumulative_supervised_seconds'])
figures=support.charts(report)
# Out:
# Decision: REVIEW_ON_OTHER_PERIODS
# Total new fits: 4
# Cumulative worker seconds: 89.233

# %% [markdown]
# ## Coverage
# Finite coverage is measured in the training prefix, not inferred from a column name.

# %%
figures[0].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Training stability
# Earlier/later associations are descriptive screening evidence, not validation performance.

# %%
figures[1].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Observation clocks
# Separately inspect missingness/timing information so it is not credited to numerical history.

# %%
figures[2].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Matched score comparison
# Compare only identical validation origins and the official-style aggregation.

# %%
figures[3].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Gains versus both controls
# Numerical panels must improve upon both the original and clock-only representations.

# %%
figures[4].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Conditional uncertainty
# Time-block intervals condition on these fitted models, not the full research history.

# %%
figures[5].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Temporal concentration
# Cumulative differences in daily rank correlation are not financial returns.

# %%
figures[6].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Admission
# Selected features are not causal explanations. Review which additions survived preprocessing.

# %%
figures[7].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Horizon subsets
# Subset metrics provide diagnostics, not a replacement for all-target performance.

# %%
figures[8].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Compute accounting
# New fits are separately counted from baseline replay and final-test evaluations.

# %%
figures[9].show(renderer='plotly_mimetype')

# %% [markdown]
# ## Decision checkpoint
# A +0.002 review gate allocates further research effort; it does not establish significance, a final model or a leaderboard record. Stop after this round.

# %%
display(pd.DataFrame(report['comparison_rows']))
print('Candidates for later review:',report['candidates_for_review'])
print('No automatic promotion:',report['promotion_allowed'])
# Out:
#    admitted                                  comparator_deltas  \
# 0         5          {'current_market': -0.003318200952792283}
# 1        14  {'current_market': 0.005703243912249911, 'erro...
# 2        14  {'current_market': 0.005843899389005647, 'erro...
# 3        23  {'current_market': -0.013542842333203908, 'err...
#
#    delta_vs_current_market                  exact_dropped_inputs  intended  \
# 0                -0.003318  [prior_error19__w63__error_coverage]         6
# 1                 0.005703  [prior_error19__w63__error_coverage]        15
# 2                 0.005844  [prior_error19__w63__error_coverage]        15
# 3                -0.013543  [prior_error19__w63__error_coverage]        24
#
#    numerical_admitted  official_metric  passes_review_gate           variant
# 0                   0         0.387301               False       error_clock
# 1                   9         0.396322                True        error_bias
# ...

# %% [markdown]
# ## Save and retain evidence
# Export only after complete analysis. A failed HTML/ZIP export does not justify refitting. Save the notebook with Ctrl+S, reopen it without execution, and confirm the inline figures persist. Keep private ZIPs off GitHub and outside this chat. Stop the AWS space after downloading.

# %%
report=support.export(ROOT,ROUND,report,figures)
print('RESULT:',report['status'])
print('REPORT:',support.report_path(ROOT,ROUND))
print('DASHBOARD:',report['dashboard'])
print('PRIVATE CHECKPOINT ZIP:',report['checkpoint_bundle']['path'])
# Out:
# RESULT: NOTEBOOK_COMPLETE
# REPORT: /home/sagemaker-user/projects/commodity-prediction-manual/logs/manual_prior_error_memory/commodity_prior_error_memory_report.json
# DASHBOARD: /home/sagemaker-user/projects/commodity-prediction-manual/logs/manual_prior_error_memory/prior_error_memory_dashboard.html
# PRIVATE CHECKPOINT ZIP: /home/sagemaker-user/projects/commodity-prediction-manual/logs/manual_prior_error_memory/prior_error_memory_checkpoints.zip
