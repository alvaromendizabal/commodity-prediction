# %% [markdown]
# # Commodity prediction · Round 14
# ## Historical surprise: magnitude, ranks and robust scale
#
# **24 candidate representations · at most four new CPU fits · ten interactive charts.** A separate study versus the frozen original baseline, not a continuation of the other round's winning model. No final test, package install, old control refit, or automatic other-fold run.

# %% [markdown]
# ## Publication provenance
#
# This is a publication copy, not a new execution. Original code cells: 15; cells with execution counts: 15; original error outputs: 0; inline Plotly outputs retained: 10. Console logs, table/HTML output, attachments and tracebacks were omitted from this copy. The original remains in the research workspace. An execution count alone is not proof of success. Refer to the linked result ledger for completed/failed/pending study status. Interactive figure data are disclosed with this public notebook.

# %%
from pathlib import Path
import importlib.util
import pandas as pd
ROOT=Path('/home/sagemaker-user/projects/commodity-prediction-manual')
ROUND=14
spec=importlib.util.spec_from_file_location('manual_two_rounds',ROOT/'scripts/commodity_two_feature_rounds.py')
support=importlib.util.module_from_spec(spec)
spec.loader.exec_module(support)
audit,session,older,u=support.previous(ROOT)
ready=u.readiness(ROOT)
u.validate_runtime(ROOT,ready)
u.validate_source(ROOT)
prior=support.read_audit(ROOT,u)
print('Source:',support.SHA)
print('Runtime:',ready['runtime']['python'])

# %% [markdown]
# ## Evidence from notebook13
#
# Released-prior time alignment was the most influential perturbed family in this audit. This is reliance of an already-fitted model, not causal importance or proof the new features will help. Only three innovation ranks passed the earlier marginal training screen.

# %%
display(pd.DataFrame(prior['reliance_summary']['rows']))
display(pd.DataFrame({'training_only_shortlist':prior['candidate_lab']['shortlist']}))

# %% [markdown]
# ## Declare comparisons before execution
#
# The full protocol in `docs/manual_innovation_ablation.md` states each formula, timing assumption, overlap and stop rule. Both rounds are frozen together; do not edit the second after observing the first. Coverage and two-half IC are audited, but not used to replace fixed feature panels after validation. The learner is unchanged.

# %%
declaration=support.plan(ROUND)
display(pd.DataFrame({'panel':declaration['variants'],'added_templates':declaration['panel_sizes']}))
print('Training stop:',support.TRAIN_STOP,'validation:',support.START,'through',support.STOP-1)
print('SAME-PERIOD control:',support.CONTROL)
print('240-second worker. Four new fits maximum. No other folds.')

# %% [markdown]
# ## Execute once
#
# This cell starts the worker, replay and up to four new fits. Do not launch both notebooks simultaneously. Each round has its own240-second allowance. STOPPED means diagnose; STOP_TESTED_PANELS means a completed negative experiment. The latter is not a software failure and does not block the independently declared next round.

# %%
report=support.run(ROOT,ROUND)
print('RESULT:',report['status'])
print('DECISION:',report['decision'])
print('New fits this call:',report['new_fits_this_notebook_call'])
figures=support.charts(report)

# %% [markdown]
# ## Starting evidence
#
# Two previous block permutations are not statistical confidence limits. No permutation outputs are used as forecasting features.

# %%
figures[0].show()

# %% [markdown]
# ## Usable coverage
#
# Finite training coverage is not proof of predictive value. Missing input histories remain missing.

# %%
figures[1].show()

# %% [markdown]
# ## Training stability
#
# Mean daily associations on two chronological fitting halves are descriptive. They do not select a validation winner.

# %%
figures[2].show()

# %% [markdown]
# ## Distributions and limits
#
# Medians and outer quantiles reveal saturation, asymmetry and low variation. Correlated transforms are not independent information sources.

# %%
figures[3].show()

# %% [markdown]
# ## Matched model scores
#
# All scores in this chart cover the same180 middle-period dates. Never compare directly to the pooled535-date score.

# %%
figures[4].show()

# %% [markdown]
# ## Incremental value
#
# A panel must beat its declared references, not merely the weakest model. Thresholds allocate further compute; no model is promoted.

# %%
figures[5].show()

# %% [markdown]
# ## Uncertainty
#
# Shown bounds condition on this round's fitted models. Both rounds and historical adaptive research create additional uncorrected multiplicity.

# %%
figures[6].show()

# %% [markdown]
# ## Time concentration
#
# Cumulative correlation differences are NOT investment profits and do not establish out-of-time stability.

# %%
figures[7].show()

# %% [markdown]
# ## Admission
#
# Recorded fit-time screening shows exactly which new inputs reached the learner. A failed admission gate prevents promotion.

# %%
figures[8].show()

# %% [markdown]
# ## Horizon behavior
#
# Subset correlations are diagnostics. They do not add up to the full424-target official metric.

# %%
figures[9].show()

# %% [markdown]
# ## Save evidence before moving on
#
# Download the JSON and HTML; keep the private model/feature ZIP off-disk. Save this notebook. A completed negative result is evidence, not a reason to repeat a run. Round15 remains independent of round14; neither launches extra folds. Stop the SageMaker space when finished.

# %%
report=support.finish(ROOT,report,figures)
display(pd.DataFrame(report['comparison_rows']))
print('RESULT:',report['status'])
print('DECISION:',report['decision'])
print('REPORT:',support.report_path(ROOT,ROUND))
print('DASHBOARD:',report['dashboard'])
print('PRIVATE ZIP:',report.get('private_checkpoint_bundle',{}).get('path',report.get('backup_warning')))
print('Ctrl+S. Download evidence; stop space after the session. No automatic shutdown.')

# %% [markdown]
# ## Research sources and cautions
#
# [Robust scaling method](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html) · [Historical-mean forecasting benchmarks](https://www.nber.org/papers/w11468) · [Risk normalization](https://onlinelibrary.wiley.com/doi/abs/10.1111/jofi.12513). These motivate hypotheses, not commodity score guarantees. Full formulas, actual source lineage and limitations are in the local protocol.
